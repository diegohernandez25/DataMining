# %% [markdown]
# # Loading and Pre Processing

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Loading the Data**
#
# We start by cloning our repository so we can access our data

# %%
# !git clone https://Colab:T74iRgyy2My5p-bxNMMZ@gitlab.com/diegohernandez25/ed-2019.git
# %cd ed-2019/
# Out:
# Cloning into 'ed-2019'...
# remote: Enumerating objects: 924, done.
# remote: Counting objects: 100% (924/924), done.
# remote: Compressing objects: 100% (698/698), done.
# remote: Total 924 (delta 174), reused 876 (delta 156), pack-reused 0
# Receiving objects: 100% (924/924), 6.78 MiB | 8.37 MiB/s, done.
# Resolving deltas: 100% (174/174), done.
# /content/ed-2019/ed-2019

# %% [markdown]
# We use "pandas" library read_csv method to transform our initial csv data into a DataFrame(this structure allows us to better work with the data and has the advantage of beeing easly transformed to and from nparray from "numpy").
#
# Our data is composed of a set of entries, each one representing values from a single trial, with 22 features (first 22 collumns) and the last collumn beeing the enviorenment that trial was made in (Training, or Testing)

# %%
data=pd.read_csv('project2/data/pre_processing/complete/completeDEI.csv')
display(data.head(10))
print('Total Number of Rows: ',data.shape)
# Out:
#    P100 PZ PEAK DISPLAY  P100 PZ LATENCY DISPLAY  ...  IMMERSION SOLUTIONS      Type
# 0         -37864.190590                    106.0  ...             0.501041  Training
# 1          42093.622190                    110.0  ...             1.079809  Training
# 2          14609.777100                    124.0  ...             0.491312  Training
# 3          26594.789980                     78.0  ...             1.847958  Training
# 4          12881.750490                    122.0  ...             0.642969  Training
# 5          11103.268900                    118.0  ...             0.136176  Training
# 6         -15150.965870                    116.0  ...             0.920084  Training
# 7           2948.983442                     76.0  ...             0.092135  Training
# 8          15574.351120                     76.0  ...             0.965169  Training
# 9          15446.238780                     88.0  ...             0.516181  Training
#
# [10 rows x 23 columns]
# ...

# %% [markdown]
# We filter our data by removing any entry that has an incomplete set of features, either having it blank or a value equal to NaN

# %%
filterData= data.dropna()
filterData.reset_index(drop=True, inplace=True)
display(filterData.head(10))
print('Total Number of Rows: ',filterData.shape)
# Out:
#    P100 PZ PEAK DISPLAY  P100 PZ LATENCY DISPLAY  ...  IMMERSION SOLUTIONS      Type
# 0         -37864.190590                    106.0  ...             0.501041  Training
# 1          42093.622190                    110.0  ...             1.079809  Training
# 2          14609.777100                    124.0  ...             0.491312  Training
# 3          26594.789980                     78.0  ...             1.847958  Training
# 4          12881.750490                    122.0  ...             0.642969  Training
# 5          11103.268900                    118.0  ...             0.136176  Training
# 6         -15150.965870                    116.0  ...             0.920084  Training
# 7           2948.983442                     76.0  ...             0.092135  Training
# 8          15574.351120                     76.0  ...             0.965169  Training
# 9          15446.238780                     88.0  ...             0.516181  Training
#
# [10 rows x 23 columns]
# ...

# %% [markdown]
# We then proceed to transform our classification collumn into booleans so its easier to work with

# %%
y = filterData['Type'] == 'Training'
print(y.head(10))
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Type, dtype: bool

# %% [markdown]
# Finally we separate our classification collumn from the rest of the data

# %%
X= filterData.copy()
del X['Type']
display(X.head(10))
# Out:
#    P100 PZ PEAK DISPLAY  ...  IMMERSION SOLUTIONS
# 0         -37864.190590  ...             0.501041
# 1          42093.622190  ...             1.079809
# 2          14609.777100  ...             0.491312
# 3          26594.789980  ...             1.847958
# 4          12881.750490  ...             0.642969
# 5          11103.268900  ...             0.136176
# 6         -15150.965870  ...             0.920084
# 7           2948.983442  ...             0.092135
# 8          15574.351120  ...             0.965169
# 9          15446.238780  ...             0.516181
#
# [10 rows x 22 columns]

# %% [markdown]
# **Normalize Features**

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
s_x = StandardScaler().fit_transform(X.values)
newX=pd.DataFrame(s_x)
newX.columns = X.columns.values.tolist()
display(newX.head(10))
# Out:
#    P100 PZ PEAK DISPLAY  ...  IMMERSION SOLUTIONS
# 0             -1.280318  ...            -0.445966
# 1              0.772096  ...            -0.294336
# 2              0.066621  ...            -0.448514
# 3              0.374261  ...            -0.093092
# 4              0.022265  ...            -0.408782
# 5             -0.023386  ...            -0.541555
# 6             -0.697298  ...            -0.336182
# 7             -0.232696  ...            -0.553093
# 8              0.091381  ...            -0.324370
# 9              0.088092  ...            -0.441999
#
# [10 rows x 22 columns]

# %% [markdown]
# Pearson Correlation

# %%
"""cor_list = []
num_feats=10
feature_name = X.columns.tolist()

for i in X.columns.tolist():
    cor = np.corrcoef(X[i], y)[0, 1]
    cor_list.append(cor)
  # replace NaN with 0
cor_list = [0 if np.isnan(i) else i for i in cor_list]
# feature name
cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
# feature selection? 0 for not select, 1 for select
cor_support = [True if i in cor_feature else False for i in feature_name]

print(cor_feature)
print(np.where(cor_support)[0])"""
# Out:
# 'cor_list = []\nnum_feats=10\nfeature_name = X.columns.tolist()\n\nfor i in X.columns.tolist():\n    cor = np.corrcoef(X[i], y)[0, 1]\n    cor_list.append(cor)\n  # replace NaN with 0\ncor_list = [0 if np.isnan(i) else i for i in cor_list]\n# feature name\ncor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()\n# feature selection? 0 for not select, 1 for select\ncor_support = [True if i in cor_feature else False for i in feature_name]\n\nprint(cor_feature)\nprint(np.where(cor_support)[0])'

# %%
#newX = newX[cor_feature]
#display(newX)

# %% [markdown]
# # Neural Network

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

from numpy.random import seed
from tensorflow import set_random_seed

# %%
X_t=newX
Y_t=y*1
display(newX)
# Out:
#      P100 PZ PEAK DISPLAY  ...  IMMERSION SOLUTIONS
# 0               -1.280318  ...            -0.445966
# 1                0.772096  ...            -0.294336
# 2                0.066621  ...            -0.448514
# 3                0.374261  ...            -0.093092
# 4                0.022265  ...            -0.408782
# ..                    ...  ...                  ...
# 867             -0.288276  ...             0.287525
# 868             -0.127181  ...             1.027577
# 869             -0.108272  ...            -0.309270
# 870             -0.151953  ...             0.645156
# 871              0.339181  ...            -0.200851
#
# [872 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X_t,Y_t,test_size=.20,random_state=42)
print("shape of X Train :"+str(X_train.shape))
print("shape of X Test :"+str(X_test.shape))
print("shape of Y Train :"+str(Y_train.shape))
print("shape of Y Test :"+str(Y_test.shape))
# Out:
# shape of X Train :(697, 22)
# shape of X Test :(175, 22)
# shape of Y Train :(697,)
# shape of Y Test :(175,)

# %%
X_train=X_train.values
X_test=X_test.values
Y_train=Y_train.values
Y_test=Y_test.values

# %%
def create_model(lyrs=[11, 5], act='linear', opt='SGD', dr=0.5):
    
    seed(42)
    set_random_seed(42)
    model = Sequential()
    model.add(Dense(lyrs[0], input_dim=X_train.shape[1], activation=act))
    
    # Generate new hidden layers 
    for i in range(1,len(lyrs)):
        model.add(Dense(lyrs[i], activation=act))
    
    # add dropout
    model.add(Dropout(dr))
    
    # output layer, sigmoid since we are dealing with a binary classificatio problem
    model.add(Dense(1, activation='sigmoid'))  
    
     # Loss function used is 'binary_crossentropy',  since we are dealing with a binary classificatio problem
     #We use accuracy to compare values further in our optimization 
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %% [markdown]
# **Optimizing Batch Size and number of epochs**

# %%
model = KerasClassifier(build_fn=create_model, verbose=0)

batch_size = [8, 16, 32, 64]
epochs = [10,20,50,100]
param_grid = dict(batch_size=batch_size, epochs=epochs)

grid = GridSearchCV(estimator=model, 
                    param_grid=param_grid,
                    cv=3,
                    verbose=2)

grid_result = grid.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] batch_size=8, epochs=10 .........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .......................... batch_size=8, epochs=10, total=  10.5s
# [CV] batch_size=8, epochs=10 .........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.5s remaining:    0.0s
# [CV] .......................... batch_size=8, epochs=10, total=  10.5s
# [CV] batch_size=8, epochs=10 .........................................
# [CV] .......................... batch_size=8, epochs=10, total=  10.5s
# [CV] batch_size=8, epochs=20 .........................................
# [CV] .......................... batch_size=8, epochs=20, total=  11.7s
# [CV] batch_size=8, epochs=20 .........................................
# [CV] .......................... batch_size=8, epochs=20, total=  11.8s
# ...

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
print("Best accuracy: %f, using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.757542 using {'batch_size': 16, 'epochs': 100}
# 0.753250 (0.025231) with: {'batch_size': 8, 'epochs': 10}
# 0.756111 (0.023808) with: {'batch_size': 8, 'epochs': 20}
# 0.757542 (0.023329) with: {'batch_size': 8, 'epochs': 50}
# 0.757542 (0.023329) with: {'batch_size': 8, 'epochs': 100}
# 0.744654 (0.025568) with: {'batch_size': 16, 'epochs': 10}
# 0.751813 (0.023208) with: {'batch_size': 16, 'epochs': 20}
# 0.756111 (0.023808) with: {'batch_size': 16, 'epochs': 50}
# 0.757542 (0.023329) with: {'batch_size': 16, 'epochs': 100}
# 0.717404 (0.022827) with: {'batch_size': 32, 'epochs': 10}
# 0.746084 (0.024294) with: {'batch_size': 32, 'epochs': 20}
# 0.754680 (0.024446) with: {'batch_size': 32, 'epochs': 50}
# 0.757542 (0.023329) with: {'batch_size': 32, 'epochs': 100}
# 0.605496 (0.041235) with: {'batch_size': 64, 'epochs': 10}
# 0.714537 (0.023327) with: {'batch_size': 64, 'epochs': 20}
# 0.751819 (0.026149) with: {'batch_size': 64, 'epochs': 50}
# ...

# %% [markdown]
# **Optimizing optimization function**

# %%
model = KerasClassifier(build_fn=create_model, epochs=10, batch_size=8, verbose=0)

optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Nadam']
param_grid = dict(opt=optimizer)

grid = GridSearchCV(estimator=model, param_grid=param_grid, verbose=2)
grid_result = grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] opt=SGD .........................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .......................................... opt=SGD, total=  14.6s
# [CV] opt=SGD .........................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   14.6s remaining:    0.0s
# [CV] .......................................... opt=SGD, total=  14.7s
# [CV] opt=SGD .........................................................
# [CV] .......................................... opt=SGD, total=  14.7s
# [CV] opt=SGD .........................................................
# [CV] .......................................... opt=SGD, total=  14.8s
# [CV] opt=SGD .........................................................
# [CV] .......................................... opt=SGD, total=  14.9s
# ...

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

print("Best accuracy: %f, using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.758993 using {'opt': 'Nadam'}
# 0.753258 (0.039077) with: {'opt': 'SGD'}
# 0.751819 (0.037738) with: {'opt': 'RMSprop'}
# 0.753248 (0.033433) with: {'opt': 'Adagrad'}
# 0.747523 (0.034482) with: {'opt': 'Adadelta'}
# 0.756125 (0.034708) with: {'opt': 'Adam'}
# 0.758993 (0.039591) with: {'opt': 'Nadam'}
# Best accuracy: 0.758993, using {'opt': 'Nadam'}

# %% [markdown]
# **Optimizing Number of Hidden layers, and their number of neurons**

# %%
model = KerasClassifier(build_fn=create_model, 
                        epochs=10, batch_size=8, verbose=0)

layers = [[6],[11],[11,11],[11,5],[12,6],[12,6,4]]
param_grid = dict(lyrs=layers)

grid = GridSearchCV(estimator=model, param_grid=param_grid, verbose=2)
grid_result = grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] lyrs=[6] ........................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ......................................... lyrs=[6], total=  17.3s
# [CV] lyrs=[6] ........................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   17.3s remaining:    0.0s
# [CV] ......................................... lyrs=[6], total=  17.3s
# [CV] lyrs=[6] ........................................................
# [CV] ......................................... lyrs=[6], total=  17.4s
# [CV] lyrs=[6] ........................................................
# [CV] ......................................... lyrs=[6], total=  17.4s
# [CV] lyrs=[6] ........................................................
# [CV] ......................................... lyrs=[6], total=  17.6s
# ...

# %%
print("Best accuracy: %f, using %s" % (grid_result.best_score_, grid_result.best_params_))

# %% [markdown]
# **Optimizing Drop Layer values**

# %%
model = KerasClassifier(build_fn=create_model, 
                        epochs=10, batch_size=8, verbose=0)

drops = [0.0, 0.01, 0.05, 0.1, 0.2, 0.5]
param_grid = dict(dr=drops)
grid = GridSearchCV(estimator=model, param_grid=param_grid, verbose=2)
grid_result = grid.fit(X_train, Y_train)

# %%
print("Best accuracy: %f, using %s" % (grid_result.best_score_, grid_result.best_params_))

# %% [markdown]
# **Final Model Using Best Configurations**

# %%
model = create_model(lyrs=[11, 5], dr=0.5, opt='SGD', act = 'relu')

print(model.summary())

training = model.fit(X_train, Y_train, epochs=10, batch_size=8, 
                     validation_split=0.2, verbose=0)

# %%
test_loss, test_acc= model.evaluate(X_test,Y_test)
print("Tested Acc: ", test_acc)
print("Tested Loss: ", test_loss)

# %%
# summarize history for accuracy
plt.plot(training.history['acc'])
plt.plot(training.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **K fold cross validation**

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,recall_score,confusion_matrix
import pandas as pd

acList=[]
recList=[]
kf = KFold(n_splits=20, shuffle=True, random_state=42)


for train_index, test_index in kf.split(X_t):
  X_train, X_test = X_t.iloc[train_index], X_t.iloc[test_index]
  Y_train, Y_test = Y_t.iloc[train_index], Y_t.iloc[test_index]

  training = model.fit(X_train, Y_train, epochs=10, batch_size=8, 
                     validation_split=0.2, verbose=0)
  
  Y_prednp = model.predict(X_test)
  Y_pred=pd.DataFrame(Y_prednp)
  Y_pred = Y_pred.apply(lambda x: round(x,0)).astype('int')
  acList.append(accuracy_score(Y_test,Y_pred))
  recList.append(recall_score(Y_test,Y_pred))

print(acList)
print(recList)

# %%
print(sum(acList)/len(recList))

# %%
a =[0.75, 0.875, 0.7471264367816092, 0.7701149425287356, 0.8275862068965517, 0.8045977011494253, 0.8505747126436781, 0.7701149425287356, 0.8045977011494253, 0.8160919540229885]
print(sum(a)/len(a))
